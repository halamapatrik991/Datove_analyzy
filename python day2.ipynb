# %% [markdown]
# # 01. Vypis, tlac

# %%
print ("ono to zije")
# Out:
# ono to zije

# %% [markdown]
# # 02. premenne a datove typy

# %%
#jednoriadkovy komentar
#Retazec (string- str)
meno_klient = "Adam"
print(meno_klient)
print("Ahoj", meno_klient)
print("Ahoj "+ meno_klient)

#intiger (int) - cele cislo
pocet_dni_vianoce = 23
print("\ndo vianoc je este", pocet_dni_vianoce, "dni")
# Out:
# Adam
# Ahoj Adam
# Ahoj Adam
#
# do vianoc je este 23 dni
